# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

# %%
#Cargar datos
data = scipy.io.loadmat('data_1.mat')

#Extraer valores
x = data['x']
y = data['y']

#Imprimir valores
plt.plot(x, y, '*', color='red');

# %%
#Cargar datos
data = scipy.io.loadmat('data_2.mat')

#Extraer valores
x = data['x']
y = data['y']

#Imprimir valores
plt.plot(x, y, '*', color='red');

# %%
#Cargar datos
data = scipy.io.loadmat('data_3.mat')

#Extraer valores
x = data['x']
y = data['y']

#Imprimir valores
plt.plot(x, y, '*', color='red');
